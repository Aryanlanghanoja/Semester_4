# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['A', 'B', 'C', 'D']
values = [23, 45, 56, 78]

# Create bar chart
plt.bar(categories, values)

# Add data labels
for i, value in enumerate(values):
    plt.text(i, value, str(value), ha='center', va='bottom',)

# Add labels and title
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart with Data Labels')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Plotting the data
plt.plot(x, y)

# Adding data labels
for i, value in enumerate(y):
    plt.text(
        x[i],  # x-coordinate
        y[i],  # y-coordinate
        str(value),  # label text
        ha="center",  # horizontal alignment
        va="bottom",  # vertical alignment
    )

# Adding title and labels
plt.title("Sample Line Chart")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Displaying the plot
plt.show()

# %%
import seaborn as sns      
import matplotlib.pyplot as plt   
import pandas as pd           

x = [1,2,3]
y = [2,3,4]
Data = pd.DataFrame({'X' : x , 'Y' : y})
sns.lineplot(data= Data , x = 'X' , y = 'Y')

for i,value in enumerate(y) :
    plt.text(x[i],y[i],str(value),ha="center",va="bottom" , weight = 'bold' , fontsize = 12)


plt.show()
